# %% [markdown]
# ## Tarea 8

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import seaborn as sns; sns.set() 
import matplotlib as mpl
import matplotlib.pyplot as plt 
import statsmodels.api as sm 
from sklearn import linear_model
import statsmodels.formula.api as smf

# %%
df = pd.read_csv('datasets/antropometria-dataset.csv')
df.head()
# Out:
#     folio  intp  entidad          desc_ent  sexo  edad  meses   peso  ropa  \
# 0  210295     2       21            PUEBLA     2    38      8  73.70     2
# 1  101655     3       10           DURANGO     2    11     11  35.65     2
# 2   10287     6        1    AGUASCALIENTES     2    18      8  54.80     1
# 3   91526     4        9  DISTRITO FEDERAL     1    10      8  33.40     2
# 4  210939     3       21            PUEBLA     2    19      3  97.95     2
#
#    talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis  \
# 0  146.4  ...    16:30      2     16:35            1     R2101        5
# 1  145.1  ...    15:25      3     15:25            1     M1041        1
# 2  162.0  ...     9:40      1      9:40            1     M0108        5
# 3  146.5  ...     7:40      3      7:45            1     M0931        4
# 4  161.0  ...     6:00      2      6:00            1     M2123        5
#
#   est_urb est_marg       pondef  est_var
# ...

# %% [markdown]
# ## Pregunta 1

# %%
## En el regression simple, cadera=  b0  + b1*peso, ¿Cual seria valor de R-squared:?
## calcular cadera respecto a peso

# %%
model = sm.OLS.from_formula('cadera~peso', data=df)
result = model.fit() 
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 cadera   R-squared:                       0.604
# Model:                            OLS   Adj. R-squared:                  0.604
# Method:                 Least Squares   F-statistic:                 2.748e+04
# Date:                Wed, 20 Oct 2021   Prob (F-statistic):               0.00
# Time:                        04:00:04   Log-Likelihood:                -65165.
# No. Observations:               18032   AIC:                         1.303e+05
# Df Residuals:                   18030   BIC:                         1.304e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     57.4600      0.252    228.032      0.000      56.966      57.954
# ...

# %% [markdown]
# ## pregunta 2

# %%
## ¿Cual seria coeficiente de correlación entre ' peso ' y 'sexo ' ?

# %%
vars = ['peso', 'sexo']

# %%
df[vars].corr()
# Out:
#           peso      sexo
# peso  1.000000 -0.124461
# sexo -0.124461  1.000000

# %% [markdown]
# ## Pregunta 3
# En el regression simple, diastol = b0+ b1*sistol + b2*edad + b3*peso + b4*cintura, ¿Cual seria valor de Durbin-Watson?

# %%
model = sm.OLS.from_formula('diastol~sistol + edad + peso + cintura',data=df)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                diastol   R-squared:                       0.458
# Model:                            OLS   Adj. R-squared:                  0.458
# Method:                 Least Squares   F-statistic:                     3812.
# Date:                Wed, 20 Oct 2021   Prob (F-statistic):               0.00
# Time:                        04:00:11   Log-Likelihood:                -63952.
# No. Observations:               18032   AIC:                         1.279e+05
# Df Residuals:                   18027   BIC:                         1.280e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     20.3297      0.520     39.089      0.000      19.310      21.349
# ...

# %% [markdown]
# ## Pregunta 4
# En el regression, diastol = b0+ b1*sistol + b2*edad + b3*peso + b4*cintura ¿Cual seria valor de b1?

# %%
model = sm.OLS.from_formula('diastol~sistol + edad + peso + cintura',data=df)
result = model.fit()
result.summary()

# %% [markdown]
# ## Pregunta 5

# %% [markdown]
# En el regression, diastol = b0+ b1*sistol + b2*edad + b3*peso + b4*cintura ¿Cual seria valor de median de los residuos?
