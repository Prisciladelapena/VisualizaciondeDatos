# %% [markdown]
# ## Actividad 2

# %%
import pandas as pd
import numpy as np

# %%
type(-4.0)
# Out:
# float

# %%
type("math.pi")
# Out:
# str

# %%
a = np.dot([2j, 3j], [2, 3j])
type(a)
# Out:
# numpy.complex128
