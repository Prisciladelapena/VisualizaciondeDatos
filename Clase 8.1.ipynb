# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %%
import pandas as pd

# %%
df=pd.read_csv('datasets/nhanes_2015_2016.csv')
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# 1     40.0     33.2     107.9     NaN
# 2     37.0     31.0     116.5     2.0
# 3     37.7     38.3     110.1     2.0
# 4     36.0     27.2      80.4     2.0
#
# [5 rows x 28 columns]

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.13.1)
# Requirement already satisfied: numpy>=1.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from statsmodels) (1.18.5)
# Requirement already satisfied: patsy>=0.5.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: pandas>=0.25 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from statsmodels) (1.0.4)
# Requirement already satisfied: scipy>=1.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from statsmodels) (1.4.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.25->statsmodels) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.25->statsmodels) (2020.1)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.7/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
import numpy as np

# %%
df.columns
# Out:
# Index(['SEQN', 'ALQ101', 'ALQ110', 'ALQ130', 'SMQ020', 'RIAGENDR', 'RIDAGEYR',
#        'RIDRETH1', 'DMDCITZN', 'DMDEDUC2', 'DMDMARTL', 'DMDHHSIZ', 'WTINT2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDFMPIR', 'BPXSY1', 'BPXDI1', 'BPXSY2',
#        'BPXDI2', 'BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML', 'BMXARMC',
#        'BMXWAIST', 'HIQ210'],
#       dtype='object')

# %%
vars=[ 'SMQ020', 'RIAGENDR', 'RIDAGEYR',
       'BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML', 'BMXARMC',
       'BMXWAIST', 'HIQ210']

# %%
df=df[vars].dropna()
df
# Out:
#       SMQ020  RIAGENDR  RIDAGEYR  BMXWT  BMXHT  BMXBMI  BMXLEG  BMXARML  \
# 0          1         1        62   94.8  184.5    27.8    43.3     43.6
# 2          1         1        78   83.4  170.1    28.8    35.6     37.0
# 3          2         2        56  109.8  160.9    42.4    38.5     37.7
# 4          2         2        42   55.2  164.9    20.3    37.4     36.0
# 7          2         2        32   64.5  151.3    28.2    34.1     33.1
# ...      ...       ...       ...    ...    ...     ...     ...      ...
# 5729       2         1        25   39.2  136.5    21.0    33.6     29.7
# 5730       1         2        76   59.1  165.8    21.5    38.2     37.0
# 5731       2         1        26  112.1  182.2    33.8    43.4     41.8
# 5733       1         1        35   78.2  173.3    26.0    40.3     37.5
# 5734       2         2        24   58.3  165.0    21.4    38.2     33.5
#
#       BMXARMC  BMXWAIST  HIQ210
# 0        35.9     101.1     2.0
# 2        31.0     116.5     2.0
# 3        38.3     110.1     2.0
# 4        27.2      80.4     2.0
# 7        31.5      93.3     2.0
# ...       ...       ...     ...
# 5729     23.8      75.4     2.0
# 5730     29.5      95.0     2.0
# 5731     42.3     110.2     2.0
# 5733     30.6      98.9     2.0
# 5734     26.2      72.5     2.0
#
# [4350 rows x 11 columns]

# %%
df.corr()
# Out:
#             SMQ020  RIAGENDR  RIDAGEYR     BMXWT     BMXHT    BMXBMI  \
# SMQ020    1.000000  0.159738 -0.165688 -0.089664 -0.143183 -0.029445
# RIAGENDR  0.159738  1.000000 -0.037139 -0.254478 -0.674012  0.061701
# RIDAGEYR -0.165688 -0.037139  1.000000 -0.014502 -0.147403  0.054957
# BMXWT    -0.089664 -0.254478 -0.014502  1.000000  0.447473  0.883163
# BMXHT    -0.143183 -0.674012 -0.147403  0.447473  1.000000 -0.010574
# BMXBMI   -0.029445  0.061701  0.054957  0.883163 -0.010574  1.000000
# BMXLEG   -0.050175 -0.525170 -0.325138  0.312194  0.780004 -0.052763
# BMXARML  -0.148854 -0.562094  0.027392  0.564747  0.789636  0.229377
# BMXARMC  -0.048752 -0.171083 -0.044068  0.901445  0.270082  0.874500
# BMXWAIST -0.114106 -0.090978  0.228709  0.889549  0.161914  0.909522
# HIQ210    0.008907 -0.026221  0.086909  0.032369  0.010522  0.027381
#
#             BMXLEG   BMXARML   BMXARMC  BMXWAIST    HIQ210
# SMQ020   -0.050175 -0.148854 -0.048752 -0.114106  0.008907
# RIAGENDR -0.525170 -0.562094 -0.171083 -0.090978 -0.026221
# RIDAGEYR -0.325138  0.027392 -0.044068  0.228709  0.086909
# BMXWT     0.312194  0.564747  0.901445  0.889549  0.032369
# BMXHT     0.780004  0.789636  0.270082  0.161914  0.010522
# BMXBMI   -0.052763  0.229377  0.874500  0.909522  0.027381
# BMXLEG    1.000000  0.608348  0.192003  0.008057 -0.006704
# BMXARML   0.608348  1.000000  0.460392  0.372971  0.032743
# BMXARMC   0.192003  0.460392  1.000000  0.811437  0.019116
# BMXWAIST  0.008057  0.372971  0.811437  1.000000  0.047161
# HIQ210   -0.006704  0.032743  0.019116  0.047161  1.000000

# %%
model=sm.OLS.from_formula('BMXWT~RIDAGEYR+RiaGENDR', data=df)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  BMXWT   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     151.9
# Date:                Fri, 26 Nov 2021   Prob (F-statistic):           1.67e-64
# Time:                        14:44:34   Log-Likelihood:                -19324.
# No. Observations:                4350   AIC:                         3.865e+04
# Df Residuals:                    4347   BIC:                         3.867e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           77.3639      0.926     83.509      0.000      75.548      79.180
# RiaGENDR[T.Male]    10.8749      0.625     17.403      0.000       9.650      12.100
# RIDAGEYR            -0.0276      0.017     -1.635      0.102      -0.061       0.005
# ==============================================================================
# Omnibus:                      577.609   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              890.611
# Skew:                           0.941   Prob(JB):                    4.04e-194
# Kurtosis:                       4.170   Cond. No.                         161.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df['RiaGENDR']=df.RIAGENDR.replace({1:'Male',2:'Female'})
df
# Out:
#       SMQ020  RIAGENDR  RIDAGEYR  BMXWT  BMXHT  BMXBMI  BMXLEG  BMXARML  \
# 0          1         1        62   94.8  184.5    27.8    43.3     43.6
# 2          1         1        78   83.4  170.1    28.8    35.6     37.0
# 3          2         2        56  109.8  160.9    42.4    38.5     37.7
# 4          2         2        42   55.2  164.9    20.3    37.4     36.0
# 7          2         2        32   64.5  151.3    28.2    34.1     33.1
# ...      ...       ...       ...    ...    ...     ...     ...      ...
# 5729       2         1        25   39.2  136.5    21.0    33.6     29.7
# 5730       1         2        76   59.1  165.8    21.5    38.2     37.0
# 5731       2         1        26  112.1  182.2    33.8    43.4     41.8
# 5733       1         1        35   78.2  173.3    26.0    40.3     37.5
# 5734       2         2        24   58.3  165.0    21.4    38.2     33.5
#
#       BMXARMC  BMXWAIST  HIQ210 RiaGENDR
# 0        35.9     101.1     2.0     Male
# 2        31.0     116.5     2.0     Male
# 3        38.3     110.1     2.0   Female
# 4        27.2      80.4     2.0   Female
# 7        31.5      93.3     2.0   Female
# ...       ...       ...     ...      ...
# 5729     23.8      75.4     2.0     Male
# 5730     29.5      95.0     2.0   Female
# 5731     42.3     110.2     2.0     Male
# 5733     30.6      98.9     2.0     Male
# 5734     26.2      72.5     2.0   Female
#
# [4350 rows x 12 columns]
